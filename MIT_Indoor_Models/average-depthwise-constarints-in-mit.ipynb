# %% [markdown]
# ## Imports and data segregation

# %%
import os
import shutil
from tqdm import tqdm
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers
import cv2
import zipfile
import shutil
import random
import pandas as pd
import csv
import os
# Paths to data and image lists
data_path = '/kaggle/input/indoor-scenes-cvpr-2019/indoorCVPR_09/Images/'
train_list_path = '/kaggle/input/indoor-scenes-cvpr-2019/TrainImages.txt'
test_list_path = '/kaggle/input/indoor-scenes-cvpr-2019/TestImages.txt'

# Output directories
output_dir = '/kaggle/working/split_data'
train_dir = os.path.join(output_dir, 'train')
val_dir = os.path.join(output_dir, 'validation')
test_dir = os.path.join(output_dir, 'test')

# Create directories for train, validation, and test splits
for folder in [train_dir, val_dir, test_dir]:
    os.makedirs(folder, exist_ok=True)

# Read train and test image lists
with open(train_list_path, 'r') as file:
    train_images = set(file.read().splitlines())

with open(test_list_path, 'r') as file:
    test_images = set(file.read().splitlines())

# Get all available images in the dataset
all_images = []
for root, _, files in os.walk(data_path):
    for file in files:
        if file.endswith(('.jpg', '.png')):
            all_images.append(os.path.join(root, file))

# Initialize counters
train_count, val_count, test_count = 0, 0, 0

# Copy images to their respective directories
for img_path in tqdm(all_images, desc="Processing images"):
    # Extract relative image path (folder_name/image_name)
    relative_path = os.path.relpath(img_path, data_path).replace("\\", "/")

    # Determine the split (train, test, or validation)
    if relative_path in train_images:
        dest_dir = train_dir
        train_count += 1
    elif relative_path in test_images:
        dest_dir = test_dir
        test_count += 1
    else:
        dest_dir = val_dir
        val_count += 1

    # Create subdirectory for the class if it doesn't exist
    class_dir = os.path.join(dest_dir, os.path.dirname(relative_path))
    os.makedirs(class_dir, exist_ok=True)

    # Copy the image
    shutil.copy(img_path, os.path.join(class_dir, os.path.basename(img_path)))

print(f"Data split complete!")
print(f"Training images: {train_count}")
print(f"Validation images: {val_count}")
print(f"Testing images: {test_count}")
# Out:
# Processing images: 100%|██████████| 15614/15614 [02:18<00:00, 112.62it/s]
# Data split complete!
# Training images: 5360
# Validation images: 8914
# Testing images: 1340

# %% [markdown]
# ## Data preprocessing

# %%
#Set data augmentation techniques
train_datagen = keras.preprocessing.image.ImageDataGenerator(horizontal_flip=True,vertical_flip=True
                                                             ,zoom_range=0.2,rotation_range=360
                                                             ,width_shift_range=0.1,height_shift_range=0.1
                                                             ,channel_shift_range=50
                                                             ,brightness_range=(0,1.2)
                                                             ,preprocessing_function=keras.applications.imagenet_utils.preprocess_input)

test_datagen = keras.preprocessing.image.ImageDataGenerator(preprocessing_function=keras.applications.imagenet_utils.preprocess_input)

# %%
#Create Data augmentation techniques
batch_size=15
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(512, 512),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True
)
validation_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(512, 512),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 5360 images belonging to 67 classes.
# Found 1340 images belonging to 67 classes.

# %% [markdown]
# ## Evaluation metrics defination

# %%
import keras
import tensorflow as tf
from sklearn.metrics import confusion_matrix
import csv
import json
import numpy as np
import matplotlib.pyplot as plt
from keras import backend as K

keras.backend.clear_session() #clear backend

# Helper function to calculate F1 Score, Sensitivity, and Specificity
def calculate_metrics(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred)
    precisions, recalls, f1_scores, specificities = [], [], [], []

    for i in range(cm.shape[0]):
        tp = cm[i, i]
        fn = cm[i, :].sum() - tp
        fp = cm[:, i].sum() - tp
        tn = cm.sum() - (tp + fn + fp)

        precision = tp / (tp + fp) if (tp + fp) > 0 else 0
        recall = tp / (tp + fn) if (tp + fn) > 0 else 0
        f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
        specificity = tn / (tn + fp) if (tn + fp) > 0 else 0

        precisions.append(precision)
        recalls.append(recall)
        f1_scores.append(f1_score)
        specificities.append(specificity)

    return {
        'f1_score': np.mean(f1_scores),
        'sensitivity': np.mean(recalls),
        'specificity': np.mean(specificities)
    }

# Custom callback to save metrics and checkpoints
class SaveMetricsAndCheckpoints(keras.callbacks.Callback):
    def __init__(self, validation_data, log_file_path='/kaggle/working/metrics_log.csv', save_interval=10):
        super().__init__()
        self.validation_data = validation_data
        self.log_file_path = log_file_path
        self.save_interval = save_interval

        # Initialize the CSV file with headers
        with open(self.log_file_path, mode='w', newline='') as file:
            writer = csv.writer(file)
            writer.writerow([
                'epoch',
                'train_loss', 'train_accuracy', 'train_precision', 'train_recall', 
                'train_top_1_accuracy', 'train_top_5_accuracy',
                'val_loss', 'val_accuracy', 'val_precision', 'val_recall',
                'val_top_1_accuracy', 'val_top_5_accuracy',
                'f1_score', 'sensitivity', 'specificity'
            ])
        print(f"Metrics will be logged to: {self.log_file_path}")

    def on_epoch_end(self, epoch, logs=None):
        # Extract validation data
        val_images, val_labels = self.validation_data
        y_pred = self.model.predict(val_images)
        y_pred_labels = tf.argmax(y_pred, axis=1).numpy()
        y_true_labels = tf.argmax(val_labels, axis=1).numpy()

        # Calculate additional metrics
        additional_metrics = calculate_metrics(y_true_labels, y_pred_labels)

        # Save metrics to the CSV file
        with open(self.log_file_path, mode='a', newline='') as file:
            writer = csv.writer(file)
            writer.writerow([
                epoch + 1,
                logs.get('loss'), logs.get('accuracy'), logs.get('precision'), logs.get('recall'),
                logs.get('top_1_accuracy'), logs.get('top_5_accuracy'),
                logs.get('val_loss'), logs.get('val_accuracy'), logs.get('val_precision'), logs.get('val_recall'),
                logs.get('val_top_1_accuracy'), logs.get('val_top_5_accuracy'),
                additional_metrics['f1_score'], additional_metrics['sensitivity'], additional_metrics['specificity']
            ])
        
        print(f"Epoch {epoch + 1}: Metrics logged.")

        # Save model checkpoint every nth epoch
        if (epoch + 1) % self.save_interval == 0:
            checkpoint_filepath = (
                f"/kaggle/working/model-"
                f"{epoch + 1:02d}-"
                f"val_acc_{logs['val_accuracy']:.4f}.keras"
            )
            self.model.save(checkpoint_filepath)
            print(f"Model checkpoint saved at: {checkpoint_filepath}")

# Validation data
validation_data = next(iter(validation_generator))

# Initialize callback
metrics_and_checkpoint_callback = SaveMetricsAndCheckpoints(
    validation_data=(validation_data[0], validation_data[1]),
    log_file_path='/kaggle/working/metrics_log.csv',
    save_interval=10
)
# Out:
# Metrics will be logged to: /kaggle/working/metrics_log.csv

# %% [markdown]
# ## Model defining and compilation

# %%
keras.backend.clear_session() #clear backend
shape=(512,512,3)
input_tensor=keras.Input(shape=shape)
base_model=keras.applications.<model_name>(input_tensor=input_tensor,weights='imagenet',include_top=False)
# Replace the model name with the models which you want to evaluate DenseNet169, ResNet50, EfficientNetB0, Xception and MobileNetV2
avg=keras.layers.AveragePooling2D(3,padding='valid')(base_model.output)
depthw=keras.layers.DepthwiseConv2D(5,
                                      depthwise_initializer=keras.initializers.RandomNormal(mean=0.0,stddev=0.01),
                                      bias_initializer=keras.initializers.Zeros(),depthwise_constraint=keras.constraints.NonNeg())(avg)
model=keras.Model(inputs=base_model.input, outputs=preds)  

##################################
for layer in model.layers:
  layer.trainable = True
#Determine adaptive learning rate with an initialization value of 0.045 and decay of 0.94 every two epochs.
lr_schedule =keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.045,
    decay_steps=2*int(len(train_generator.filenames)/batch_size),
    decay_rate=0.94,
    staircase=True)
optimizer=keras.optimizers.SGD(momentum=0.9,learning_rate=lr_schedule)
# Compile the model
model.compile(
    optimizer=optimizer,
    loss='categorical_crossentropy',
    metrics=[
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall'),
        tf.keras.metrics.TopKCategoricalAccuracy(k=1, name='top_1_accuracy'),
        tf.keras.metrics.TopKCategoricalAccuracy(k=5, name='top_5_accuracy')
    ]
)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# ## Model Fitting

# %%
hist=model.fit(
    train_generator, 
    epochs=130,
    validation_data=validation_generator,
    shuffle=True,
    callbacks=metrics_and_checkpoint_callback) #start training
# Out:
# Epoch 1/130
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1734156888.000264     106 service.cc:145] XLA service 0x79c078003ce0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1734156888.000329     106 service.cc:153]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1734156888.000335     106 service.cc:153]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# 2024-12-14 06:15:13.524603: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng4{} for conv (f32[15,96,257,257]{3,2,1,0}, u8[0]{0}) custom-call(f32[15,96,259,259]{3,2,1,0}, f32[96,1,3,3]{3,2,1,0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, feature_group_count=96, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2024-12-14 06:15:13.652535: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.128039078s
# Trying algorithm eng4{} for conv (f32[15,96,257,257]{3,2,1,0}, u8[0]{0}) custom-call(f32[15,96,259,259]{3,2,1,0}, f32[96,1,3,3]{3,2,1,0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, feature_group_count=96, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# I0000 00:00:1734156940.994599     106 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/stepstep - accuracy: 0.1315 - loss: 3.6599 - precision: 0.4087 - recall: 0.0193 - top_1_accuracy: 0.1315 - top_5_accuracy: 0.332
# Epoch 1: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 476s 1s/step - accuracy: 0.1316 - loss: 3.6590 - precision: 0.4090 - recall: 0.0193 - top_1_accuracy: 0.1316 - top_5_accuracy: 0.3326 - val_accuracy: 0.2485 - val_loss: 3.0686 - val_precision: 0.4190 - val_recall: 0.1351 - val_top_1_accuracy: 0.2485 - val_top_5_accuracy: 0.5813
# Epoch 2/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step/step - accuracy: 0.2961 - loss: 2.6856 - precision: 0.6126 - recall: 0.1206 - top_1_accuracy: 0.2961 - top_5_accuracy: 0.629
# Epoch 2: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 357s 977ms/step - accuracy: 0.2961 - loss: 2.6855 - precision: 0.6126 - recall: 0.1207 - top_1_accuracy: 0.2961 - top_5_accuracy: 0.6291 - val_accuracy: 0.3060 - val_loss: 2.9232 - val_precision: 0.5262 - val_recall: 0.1873 - val_top_1_accuracy: 0.3060 - val_top_5_accuracy: 0.6067
# Epoch 3/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step/step - accuracy: 0.4047 - loss: 2.1624 - precision: 0.6884 - recall: 0.2137 - top_1_accuracy: 0.4047 - top_5_accuracy: 0.749
# Epoch 3: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 356s 975ms/step - accuracy: 0.4047 - loss: 2.1623 - precision: 0.6883 - recall: 0.2138 - top_1_accuracy: 0.4047 - top_5_accuracy: 0.7494 - val_accuracy: 0.3284 - val_loss: 2.7511 - val_precision: 0.5059 - val_recall: 0.2239 - val_top_1_accuracy: 0.3284 - val_top_5_accuracy: 0.6567
# Epoch 4/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step/step - accuracy: 0.4769 - loss: 1.8722 - precision: 0.7219 - recall: 0.3011 - top_1_accuracy: 0.4769 - top_5_accuracy: 0.801
# Epoch 4: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 354s 970ms/step - accuracy: 0.4769 - loss: 1.8723 - precision: 0.7219 - recall: 0.3011 - top_1_accuracy: 0.4769 - top_5_accuracy: 0.8017 - val_accuracy: 0.2231 - val_loss: 3.4298 - val_precision: 0.3692 - val_recall: 0.1433 - val_top_1_accuracy: 0.2231 - val_top_5_accuracy: 0.5000
# Epoch 5/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step/step - accuracy: 0.5327 - loss: 1.6813 - precision: 0.7383 - recall: 0.3664 - top_1_accuracy: 0.5327 - top_5_accuracy: 0.829
# Epoch 5: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 356s 976ms/step - accuracy: 0.5327 - loss: 1.6813 - precision: 0.7383 - recall: 0.3664 - top_1_accuracy: 0.5327 - top_5_accuracy: 0.8290 - val_accuracy: 0.4269 - val_loss: 2.3066 - val_precision: 0.5685 - val_recall: 0.3313 - val_top_1_accuracy: 0.4269 - val_top_5_accuracy: 0.7448
# Epoch 6/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step/step - accuracy: 0.5956 - loss: 1.4375 - precision: 0.7917 - recall: 0.4492 - top_1_accuracy: 0.5956 - top_5_accuracy: 0.875
# Epoch 6: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 356s 976ms/step - accuracy: 0.5956 - loss: 1.4376 - precision: 0.7917 - recall: 0.4492 - top_1_accuracy: 0.5956 - top_5_accuracy: 0.8757 - val_accuracy: 0.4657 - val_loss: 2.1344 - val_precision: 0.5748 - val_recall: 0.3784 - val_top_1_accuracy: 0.4657 - val_top_5_accuracy: 0.8082
# Epoch 7/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step/step - accuracy: 0.6297 - loss: 1.2487 - precision: 0.8045 - recall: 0.5047 - top_1_accuracy: 0.6297 - top_5_accuracy: 0.902
# Epoch 7: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 355s 973ms/step - accuracy: 0.6297 - loss: 1.2487 - precision: 0.8045 - recall: 0.5047 - top_1_accuracy: 0.6297 - top_5_accuracy: 0.9022 - val_accuracy: 0.4866 - val_loss: 2.0807 - val_precision: 0.6002 - val_recall: 0.4090 - val_top_1_accuracy: 0.4866 - val_top_5_accuracy: 0.7881
# Epoch 8/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step/step - accuracy: 0.6790 - loss: 1.1267 - precision: 0.8326 - recall: 0.5628 - top_1_accuracy: 0.6790 - top_5_accuracy: 0.915
# Epoch 8: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 355s 972ms/step - accuracy: 0.6790 - loss: 1.1268 - precision: 0.8326 - recall: 0.5628 - top_1_accuracy: 0.6790 - top_5_accuracy: 0.9157 - val_accuracy: 0.5022 - val_loss: 2.0250 - val_precision: 0.6087 - val_recall: 0.4366 - val_top_1_accuracy: 0.5022 - val_top_5_accuracy: 0.8239
# Epoch 9/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step/step - accuracy: 0.7413 - loss: 0.9040 - precision: 0.8607 - recall: 0.6444 - top_1_accuracy: 0.7413 - top_5_accuracy: 0.940
# Epoch 9: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 355s 974ms/step - accuracy: 0.7412 - loss: 0.9041 - precision: 0.8607 - recall: 0.6443 - top_1_accuracy: 0.7412 - top_5_accuracy: 0.9405 - val_accuracy: 0.5209 - val_loss: 1.9262 - val_precision: 0.6398 - val_recall: 0.4440 - val_top_1_accuracy: 0.5209 - val_top_5_accuracy: 0.8254
# Epoch 10/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step/step - accuracy: 0.7455 - loss: 0.8450 - precision: 0.8519 - recall: 0.6511 - top_1_accuracy: 0.7455 - top_5_accuracy: 0.951
# Epoch 10: Metrics logged.
# Model checkpoint saved at: /kaggle/working/model-10-val_acc_0.4716.keras
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 356s 976ms/step - accuracy: 0.7455 - loss: 0.8451 - precision: 0.8519 - recall: 0.6511 - top_1_accuracy: 0.7455 - top_5_accuracy: 0.9510 - val_accuracy: 0.4716 - val_loss: 2.3033 - val_precision: 0.5618 - val_recall: 0.4306 - val_top_1_accuracy: 0.4716 - val_top_5_accuracy: 0.8104
# Epoch 11/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step/step - accuracy: 0.8005 - loss: 0.6978 - precision: 0.8955 - recall: 0.7222 - top_1_accuracy: 0.8005 - top_5_accuracy: 0.962
# Epoch 11: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 355s 973ms/step - accuracy: 0.8005 - loss: 0.6978 - precision: 0.8955 - recall: 0.7221 - top_1_accuracy: 0.8005 - top_5_accuracy: 0.9620 - val_accuracy: 0.5612 - val_loss: 1.9012 - val_precision: 0.6378 - val_recall: 0.5112 - val_top_1_accuracy: 0.5612 - val_top_5_accuracy: 0.8425
# Epoch 12/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step/step - accuracy: 0.8272 - loss: 0.5919 - precision: 0.9034 - recall: 0.7513 - top_1_accuracy: 0.8272 - top_5_accuracy: 0.973
# Epoch 12: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 355s 972ms/step - accuracy: 0.8271 - loss: 0.5921 - precision: 0.9034 - recall: 0.7512 - top_1_accuracy: 0.8271 - top_5_accuracy: 0.9735 - val_accuracy: 0.5761 - val_loss: 1.7352 - val_precision: 0.6604 - val_recall: 0.5254 - val_top_1_accuracy: 0.5761 - val_top_5_accuracy: 0.8619
# Epoch 13/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step/step - accuracy: 0.8329 - loss: 0.5674 - precision: 0.9071 - recall: 0.7667 - top_1_accuracy: 0.8329 - top_5_accuracy: 0.974
# Epoch 13: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 355s 971ms/step - accuracy: 0.8329 - loss: 0.5675 - precision: 0.9071 - recall: 0.7667 - top_1_accuracy: 0.8329 - top_5_accuracy: 0.9748 - val_accuracy: 0.5754 - val_loss: 1.8277 - val_precision: 0.6618 - val_recall: 0.5373 - val_top_1_accuracy: 0.5754 - val_top_5_accuracy: 0.8612
# Epoch 14/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step/step - accuracy: 0.8637 - loss: 0.4648 - precision: 0.9290 - recall: 0.8144 - top_1_accuracy: 0.8637 - top_5_accuracy: 0.979
# Epoch 14: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 359s 983ms/step - accuracy: 0.8637 - loss: 0.4649 - precision: 0.9290 - recall: 0.8143 - top_1_accuracy: 0.8637 - top_5_accuracy: 0.9794 - val_accuracy: 0.5739 - val_loss: 1.7794 - val_precision: 0.6542 - val_recall: 0.5336 - val_top_1_accuracy: 0.5739 - val_top_5_accuracy: 0.8739
# Epoch 15/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step/step - accuracy: 0.8657 - loss: 0.4310 - precision: 0.9247 - recall: 0.8193 - top_1_accuracy: 0.8657 - top_5_accuracy: 0.983
# Epoch 15: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 354s 971ms/step - accuracy: 0.8657 - loss: 0.4310 - precision: 0.9246 - recall: 0.8193 - top_1_accuracy: 0.8657 - top_5_accuracy: 0.9839 - val_accuracy: 0.6067 - val_loss: 1.7268 - val_precision: 0.6722 - val_recall: 0.5694 - val_top_1_accuracy: 0.6067 - val_top_5_accuracy: 0.8746
# Epoch 16/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step/step - accuracy: 0.8881 - loss: 0.3682 - precision: 0.9359 - recall: 0.8430 - top_1_accuracy: 0.8881 - top_5_accuracy: 0.987
# Epoch 16: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 355s 973ms/step - accuracy: 0.8881 - loss: 0.3682 - precision: 0.9359 - recall: 0.8430 - top_1_accuracy: 0.8881 - top_5_accuracy: 0.9875 - val_accuracy: 0.6246 - val_loss: 1.6929 - val_precision: 0.6894 - val_recall: 0.5896 - val_top_1_accuracy: 0.6246 - val_top_5_accuracy: 0.8836
# Epoch 17/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step/step - accuracy: 0.9075 - loss: 0.3207 - precision: 0.9511 - recall: 0.8777 - top_1_accuracy: 0.9075 - top_5_accuracy: 0.984
# Epoch 17: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 355s 972ms/step - accuracy: 0.9075 - loss: 0.3207 - precision: 0.9511 - recall: 0.8777 - top_1_accuracy: 0.9075 - top_5_accuracy: 0.9848 - val_accuracy: 0.6134 - val_loss: 1.7483 - val_precision: 0.6848 - val_recall: 0.5821 - val_top_1_accuracy: 0.6134 - val_top_5_accuracy: 0.8724
# Epoch 18/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step/step - accuracy: 0.9162 - loss: 0.2823 - precision: 0.9464 - recall: 0.8913 - top_1_accuracy: 0.9162 - top_5_accuracy: 0.988
# Epoch 18: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 355s 974ms/step - accuracy: 0.9162 - loss: 0.2823 - precision: 0.9464 - recall: 0.8913 - top_1_accuracy: 0.9162 - top_5_accuracy: 0.9884 - val_accuracy: 0.5881 - val_loss: 1.9220 - val_precision: 0.6503 - val_recall: 0.5619 - val_top_1_accuracy: 0.5881 - val_top_5_accuracy: 0.8724
# Epoch 19/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step/step - accuracy: 0.9336 - loss: 0.2274 - precision: 0.9615 - recall: 0.9086 - top_1_accuracy: 0.9336 - top_5_accuracy: 0.992
# Epoch 19: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 354s 971ms/step - accuracy: 0.9336 - loss: 0.2275 - precision: 0.9615 - recall: 0.9086 - top_1_accuracy: 0.9336 - top_5_accuracy: 0.9923 - val_accuracy: 0.6485 - val_loss: 1.5224 - val_precision: 0.7079 - val_recall: 0.6187 - val_top_1_accuracy: 0.6485 - val_top_5_accuracy: 0.9022
# Epoch 20/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step/step - accuracy: 0.9359 - loss: 0.2192 - precision: 0.9612 - recall: 0.9164 - top_1_accuracy: 0.9359 - top_5_accuracy: 0.992
# Epoch 20: Metrics logged.
# Model checkpoint saved at: /kaggle/working/model-20-val_acc_0.6291.keras
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 355s 974ms/step - accuracy: 0.9359 - loss: 0.2192 - precision: 0.9612 - recall: 0.9164 - top_1_accuracy: 0.9359 - top_5_accuracy: 0.9924 - val_accuracy: 0.6291 - val_loss: 1.7328 - val_precision: 0.6796 - val_recall: 0.6000 - val_top_1_accuracy: 0.6291 - val_top_5_accuracy: 0.8866
# Epoch 21/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/
130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step/step - accuracy: 0.9669 - loss: 0.1277 - precision: 0.9854 - recall: 0.9604 - top_1_accuracy: 0.9669 - top_5_accuracy: 0.991
# Epoch 27: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 354s 971ms/step - accuracy: 0.9669 - loss: 0.1277 - precision: 0.9854 - recall: 0.9604 - top_1_accuracy: 0.9669 - top_5_accuracy: 0.9910 - val_accuracy: 0.6470 - val_loss: 1.6203 - val_precision: 0.7072 - val_recall: 0.6254 - val_top_1_accuracy: 0.6470 - val_top_5_accuracy: 0.9007
# Epoch 28/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step/step - accuracy: 0.9757 - loss: 0.1025 - precision: 0.9884 - recall: 0.9689 - top_1_accuracy: 0.9757 - top_5_accuracy: 0.992
# Epoch 28: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 354s 970ms/step - accuracy: 0.9757 - loss: 0.1025 - precision: 0.9884 - recall: 0.9689 - top_1_accuracy: 0.9757 - top_5_accuracy: 0.9926 - val_accuracy: 0.6731 - val_loss: 1.5383 - val_precision: 0.7119 - val_recall: 0.6455 - val_top_1_accuracy: 0.6731 - val_top_5_accuracy: 0.9112
# Epoch 29/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step/step - accuracy: 0.9744 - loss: 0.1029 - precision: 0.9862 - recall: 0.9663 - top_1_accuracy: 0.9744 - top_5_accuracy: 0.994
# Epoch 29: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 360s 987ms/step - accuracy: 0.9744 - loss: 0.1029 - precision: 0.9862 - recall: 0.9663 - top_1_accuracy: 0.9744 - top_5_accuracy: 0.9940 - val_accuracy: 0.6799 - val_loss: 1.5428 - val_precision: 0.7256 - val_recall: 0.6590 - val_top_1_accuracy: 0.6799 - val_top_5_accuracy: 0.9224
# Epoch 30/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step/step - accuracy: 0.9779 - loss: 0.0825 - precision: 0.9868 - recall: 0.9732 - top_1_accuracy: 0.9779 - top_5_accuracy: 0.995
# Epoch 30: Metrics logged.
# Model checkpoint saved at: /kaggle/working/model-30-val_acc_0.6672.keras
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 370s 1s/step - accuracy: 0.9779 - loss: 0.0825 - precision: 0.9868 - recall: 0.9732 - top_1_accuracy: 0.9779 - top_5_accuracy: 0.9959 - val_accuracy: 0.6672 - val_loss: 1.6043 - val_precision: 0.7095 - val_recall: 0.6507 - val_top_1_accuracy: 0.6672 - val_top_5_accuracy: 0.9134
# Epoch 31/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step/step - accuracy: 0.9793 - loss: 0.0854 - precision: 0.9849 - recall: 0.9730 - top_1_accuracy: 0.9793 - top_5_accuracy: 0.997
# Epoch 31: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 366s 1s/step - accuracy: 0.9793 - loss: 0.0854 - precision: 0.9849 - recall: 0.9730 - top_1_accuracy: 0.9793 - top_5_accuracy: 0.9971 - val_accuracy: 0.6761 - val_loss: 1.5285 - val_precision: 0.7220 - val_recall: 0.6590 - val_top_1_accuracy: 0.6761 - val_top_5_accuracy: 0.9164
# Epoch 32/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step/step - accuracy: 0.9769 - loss: 0.0984 - precision: 0.9884 - recall: 0.9727 - top_1_accuracy: 0.9769 - top_5_accuracy: 0.991
# Epoch 32: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 360s 986ms/step - accuracy: 0.9769 - loss: 0.0984 - precision: 0.9884 - recall: 0.9727 - top_1_accuracy: 0.9769 - top_5_accuracy: 0.9917 - val_accuracy: 0.6612 - val_loss: 1.6515 - val_precision: 0.7049 - val_recall: 0.6418 - val_top_1_accuracy: 0.6612 - val_top_5_accuracy: 0.9134
# Epoch 33/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/
Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 359s 984ms/step - accuracy: 0.9882 - loss: 0.0517 - precision: 0.9946 - recall: 0.9852 - top_1_accuracy: 0.9882 - top_5_accuracy: 0.9959 - val_accuracy: 0.7030 - val_loss: 1.4389 - val_precision: 0.7463 - val_recall: 0.6761 - val_top_1_accuracy: 0.7030 - val_top_5_accuracy: 0.9254
# Epoch 45/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step/step - accuracy: 0.9849 - loss: 0.0617 - precision: 0.9922 - recall: 0.9812 - top_1_accuracy: 0.9849 - top_5_accuracy: 0.995
# Epoch 45: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 357s 978ms/step - accuracy: 0.9849 - loss: 0.0617 - precision: 0.9922 - recall: 0.9812 - top_1_accuracy: 0.9849 - top_5_accuracy: 0.9954 - val_accuracy: 0.6970 - val_loss: 1.4707 - val_precision: 0.7388 - val_recall: 0.6799 - val_top_1_accuracy: 0.6970 - val_top_5_accuracy: 0.9224
# Epoch 46/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step/step - accuracy: 0.9840 - loss: 0.0664 - precision: 0.9940 - recall: 0.9807 - top_1_accuracy: 0.9840 - top_5_accuracy: 0.993
# Epoch 46: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 356s 975ms/step - accuracy: 0.9840 - loss: 0.0664 - precision: 0.9940 - recall: 0.9807 - top_1_accuracy: 0.9840 - top_5_accuracy: 0.9931 - val_accuracy: 0.6918 - val_loss: 1.4673 - val_precision: 0.7384 - val_recall: 0.6784 - val_top_1_accuracy: 0.6918 - val_top_5_accuracy: 0.9187
# Epoch 47/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step/step - accuracy: 0.9878 - loss: 0.0508 - precision: 0.9940 - recall: 0.9858 - top_1_accuracy: 0.9878 - top_5_accuracy: 0.995
# Epoch 47: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 356s 974ms/step - accuracy: 0.9878 - loss: 0.0508 - precision: 0.9940 - recall: 0.9858 - top_1_accuracy: 0.9878 - top_5_accuracy: 0.9958 - val_accuracy: 0.6985 - val_loss: 1.4692 - val_precision: 0.7335 - val_recall: 0.6739 - val_top_1_accuracy: 0.6985 - val_top_5_accuracy: 0.9291
# Epoch 48/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step/step - accuracy: 0.9850 - loss: 0.0606 - precision: 0.9954 - recall: 0.9835 - top_1_accuracy: 0.9850 - top_5_accuracy: 0.994
# Epoch 48: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 356s 976ms/step - accuracy: 0.9850 - loss: 0.0606 - precision: 0.9954 - recall: 0.9835 - top_1_accuracy: 0.9850 - top_5_accuracy: 0.9942 - val_accuracy: 0.7000 - val_loss: 1.4887 - val_precision: 0.7402 - val_recall: 0.6761 - val_top_1_accuracy: 0.7000 - val_top_5_accuracy: 0.9194
# Epoch 49/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step/step - accuracy: 0.9847 - loss: 0.0605 - precision: 0.9949 - recall: 0.9818 - top_1_accuracy: 0.9847 - top_5_accuracy: 0.993
# Epoch 49: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 358s 979ms/step - accuracy: 0.9847 - loss: 0.0605 - precision: 0.9949 - recall: 0.9818 - top_1_accuracy: 0.9847 - top_5_accuracy: 0.9931 - val_accuracy: 0.6910 - val_loss: 1.4603 - val_precision: 0.7374 - val_recall: 0.6769 - val_top_1_accuracy: 0.6910 - val_top_5_accuracy: 0.9231
# Epoch 50/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step/step - accuracy: 0.9849 - loss: 0.0563 - precision: 0.9930 - recall: 0.9834 - top_1_accuracy: 0.9849 - top_5_accuracy: 0.995
# Epoch 50: Metrics logged.
# Model checkpoint saved at: /kaggle/working/model-50-val_acc_0.7022.keras
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 356s 975ms/step - accuracy: 0.9849 - loss: 0.0563 - precision: 0.9930 - recall: 0.9834 - top_1_accuracy: 0.9849 - top_5_accuracy: 0.9952 - val_accuracy: 0.7022 - val_loss: 1.4331 - val_precision: 0.7514 - val_recall: 0.6813 - val_top_1_accuracy: 0.7022 - val_top_5_accuracy: 0.9224
# Epoch 51/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step/step - accuracy: 0.9844 - loss: 0.0596 - precision: 0.9928 - recall: 0.9819 - top_1_accuracy: 0.9844 - top_5_accuracy: 0.994
# Epoch 51: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 356s 975ms/step - accuracy: 0.9844 - loss: 0.0595 - precision: 0.9928 - recall: 0.9819 - top_1_accuracy: 0.9844 - top_5_accuracy: 0.9941 - val_accuracy: 0.7060 - val_loss: 1.4227 - val_precision: 0.7547 - val_recall: 0.6888 - val_top_1_accuracy: 0.7060 - val_top_5_accuracy: 0.9201
# Epoch 52/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step/step - accuracy: 0.9905 - loss: 0.0435 - precision: 0.9963 - recall: 0.9877 - top_1_accuracy: 0.9905 - top_5_accuracy: 0.995
# Epoch 52: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 354s 971ms/step - accuracy: 0.9905 - loss: 0.0435 - precision: 0.9963 - recall: 0.9877 - top_1_accuracy: 0.9905 - top_5_accuracy: 0.9957 - val_accuracy: 0.7060 - val_loss: 1.4614 - val_precision: 0.7533 - val_recall: 0.6858 - val_top_1_accuracy: 0.7060 - val_top_5_accuracy: 0.9209
# Epoch 53/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step/step - accuracy: 0.9883 - loss: 0.0453 - precision: 0.9957 - recall: 0.9868 - top_1_accuracy: 0.9883 - top_5_accuracy: 0.994
# Epoch 53: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 354s 970ms/step - accuracy: 0.9883 - loss: 0.0453 - precision: 0.9957 - recall: 0.9868 - top_1_accuracy: 0.9883 - top_5_accuracy: 0.9945 - val_accuracy: 0.7067 - val_loss: 1.4688 - val_precision: 0.7478 - val_recall: 0.6858 - val_top_1_accuracy: 0.7067 - val_top_5_accuracy: 0.9209
# Epoch 54/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step/step - accuracy: 0.9887 - loss: 0.0509 - precision: 0.9966 - recall: 0.9851 - top_1_accuracy: 0.9887 - top_5_accuracy: 0.994
# Epoch 54: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 358s 980ms/step - accuracy: 0.9887 - loss: 0.0509 - precision: 0.9966 - recall: 0.9851 - top_1_accuracy: 0.9887 - top_5_accuracy: 0.9944 - val_accuracy: 0.6978 - val_loss: 1.4801 - val_precision: 0.7383 - val_recall: 0.6821 - val_top_1_accuracy: 0.6978 - val_top_5_accuracy: 0.9224
# Epoch 55/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step/step - accuracy: 0.9913 - loss: 0.0368 - precision: 0.9959 - recall: 0.9908 - top_1_accuracy: 0.9913 - top_5_accuracy: 0.996
# Epoch 55: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 353s 968ms/step - accuracy: 0.9913 - loss: 0.0369 - precision: 0.9959 - recall: 0.9908 - top_1_accuracy: 0.9913 - top_5_accuracy: 0.9966 - val_accuracy: 0.6993 - val_loss: 1.4629 - val_precision: 0.7376 - val_recall: 0.6776 - val_top_1_accuracy: 0.6993 - val_top_5_accuracy: 0.9239
# Epoch 56/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step/step - accuracy: 0.9916 - loss: 0.0402 - precision: 0.9973 - recall: 0.9893 - top_1_accuracy: 0.9916 - top_5_accuracy: 0.995
# Epoch 56: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 354s 971ms/step - accuracy: 0.9916 - loss: 0.0402 - precision: 0.9973 - recall: 0.9893 - top_1_accuracy: 0.9916 - top_5_accuracy: 0.9957 - val_accuracy: 0.7000 - val_loss: 1.4878 - val_precision: 0.7329 - val_recall: 0.6799 - val_top_1_accuracy: 0.7000 - val_top_5_accuracy: 0.9194
# Epoch 57/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step/step - accuracy: 0.9888 - loss: 0.0429 - precision: 0.9942 - recall: 0.9869 - top_1_accuracy: 0.9888 - top_5_accuracy: 0.996
# Epoch 57: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 359s 983ms/step - accuracy: 0.9888 - loss: 0.0429 - precision: 0.9942 - recall: 0.9869 - top_1_accuracy: 0.9888 - top_5_accuracy: 0.9964 - val_accuracy: 0.6993 - val_loss: 1.4909 - val_precision: 0.7426 - val_recall: 0.6784 - val_top_1_accuracy: 0.6993 - val_top_5_accuracy: 0.9246
# Epoch 58/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step/step - accuracy: 0.9869 - loss: 0.0507 - precision: 0.9947 - recall: 0.9852 - top_1_accuracy: 0.9869 - top_5_accuracy: 0.995
# Epoch 58: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 359s 984ms/step - accuracy: 0.9869 - loss: 0.0507 - precision: 0.9947 - recall: 0.9852 - top_1_accuracy: 0.9869 - top_5_accuracy: 0.9954 - val_accuracy: 0.6918 - val_loss: 1.4827 - val_precision: 0.7404 - val_recall: 0.6746 - val_top_1_accuracy: 0.6918 - val_top_5_accuracy: 0.9231
# Epoch 59/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step/step - accuracy: 0.9880 - loss: 0.0514 - precision: 0.9962 - recall: 0.9858 - top_1_accuracy: 0.9880 - top_5_accuracy: 0.994
# Epoch 59: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 357s 977ms/step - accuracy: 0.9880 - loss: 0.0513 - precision: 0.9962 - recall: 0.9858 - top_1_accuracy: 0.9880 - top_5_accuracy: 0.9944 - val_accuracy: 0.6955 - val_loss: 1.4869 - val_precision: 0.7384 - val_recall: 0.6761 - val_top_1_accuracy: 0.6955 - val_top_5_accuracy: 0.9209
# Epoch 60/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step/step - accuracy: 0.9913 - loss: 0.0404 - precision: 0.9969 - recall: 0.9893 - top_1_accuracy: 0.9913 - top_5_accuracy: 0.996
# Epoch 60: Metrics logged.
# Model checkpoint saved at: /kaggle/working/model-60-val_acc_0.6918.keras
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 357s 978ms/step - accuracy: 0.9913 - loss: 0.0404 - precision: 0.9969 - recall: 0.9893 - top_1_accuracy: 0.9913 - top_5_accuracy: 0.9961 - val_accuracy: 0.6918 - val_loss: 1.4704 - val_precision: 0.7358 - val_recall: 0.6694 - val_top_1_accuracy: 0.6918 - val_top_5_accuracy: 0.9201
# Epoch 61/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step/step - accuracy: 0.9901 - loss: 0.0400 - precision: 0.9949 - recall: 0.9880 - top_1_accuracy: 0.9901 - top_5_accuracy: 0.996
# Epoch 61: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 355s 972ms/step - accuracy: 0.9901 - loss: 0.0400 - precision: 0.9949 - recall: 0.9880 - top_1_accuracy: 0.9901 - top_5_accuracy: 0.9968 - val_accuracy: 0.7052 - val_loss: 1.4697 - val_precision: 0.7480 - val_recall: 0.6866 - val_top_1_accuracy: 0.7052 - val_top_5_accuracy: 0.9209
# Epoch 62/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/
130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step/step - accuracy: 0.9907 - loss: 0.0348 - precision: 0.9955 - recall: 0.9898 - top_1_accuracy: 0.9907 - top_5_accuracy: 0.996
# Epoch 68: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 355s 973ms/step - accuracy: 0.9907 - loss: 0.0348 - precision: 0.9955 - recall: 0.9898 - top_1_accuracy: 0.9907 - top_5_accuracy: 0.9968 - val_accuracy: 0.7104 - val_loss: 1.4568 - val_precision: 0.7516 - val_recall: 0.6910 - val_top_1_accuracy: 0.7104 - val_top_5_accuracy: 0.9216
# Epoch 69/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step/step - accuracy: 0.9883 - loss: 0.0500 - precision: 0.9958 - recall: 0.9869 - top_1_accuracy: 0.9883 - top_5_accuracy: 0.995
# Epoch 69: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 358s 982ms/step - accuracy: 0.9883 - loss: 0.0500 - precision: 0.9958 - recall: 0.9869 - top_1_accuracy: 0.9883 - top_5_accuracy: 0.9954 - val_accuracy: 0.7104 - val_loss: 1.4523 - val_precision: 0.7525 - val_recall: 0.6873 - val_top_1_accuracy: 0.7104 - val_top_5_accuracy: 0.9216
# Epoch 70/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step/step - accuracy: 0.9888 - loss: 0.0490 - precision: 0.9968 - recall: 0.9873 - top_1_accuracy: 0.9888 - top_5_accuracy: 0.992
# Epoch 70: Metrics logged.
# Model checkpoint saved at: /kaggle/working/model-70-val_acc_0.7060.keras
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 356s 974ms/step - accuracy: 0.9888 - loss: 0.0490 - precision: 0.9968 - recall: 0.9873 - top_1_accuracy: 0.9888 - top_5_accuracy: 0.9926 - val_accuracy: 0.7060 - val_loss: 1.4610 - val_precision: 0.7449 - val_recall: 0.6866 - val_top_1_accuracy: 0.7060 - val_top_5_accuracy: 0.9239
# Epoch 71/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step/step - accuracy: 0.9907 - loss: 0.0389 - precision: 0.9967 - recall: 0.9874 - top_1_accuracy: 0.9907 - top_5_accuracy: 0.995
# Epoch 71: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 357s 977ms/step - accuracy: 0.9907 - loss: 0.0389 - precision: 0.9967 - recall: 0.9874 - top_1_accuracy: 0.9907 - top_5_accuracy: 0.9953 - val_accuracy: 0.7090 - val_loss: 1.4316 - val_precision: 0.7494 - val_recall: 0.6896 - val_top_1_accuracy: 0.7090 - val_top_5_accuracy: 0.9246
# Epoch 72/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step/step - accuracy: 0.9902 - loss: 0.0385 - precision: 0.9967 - recall: 0.9883 - top_1_accuracy: 0.9902 - top_5_accuracy: 0.995
# Epoch 72: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 357s 977ms/step - accuracy: 0.9902 - loss: 0.0385 - precision: 0.9967 - recall: 0.9883 - top_1_accuracy: 0.9902 - top_5_accuracy: 0.9958 - val_accuracy: 0.7082 - val_loss: 1.4532 - val_precision: 0.7405 - val_recall: 0.6836 - val_top_1_accuracy: 0.7082 - val_top_5_accuracy: 0.9246
# Epoch 73/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step/step - accuracy: 0.9896 - loss: 0.0481 - precision: 0.9982 - recall: 0.9880 - top_1_accuracy: 0.9896 - top_5_accuracy: 0.993
# Epoch 73: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━
Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 367s 1s/step - accuracy: 0.9861 - loss: 0.0487 - precision: 0.9935 - recall: 0.9844 - top_1_accuracy: 0.9861 - top_5_accuracy: 0.9943 - val_accuracy: 0.7090 - val_loss: 1.4445 - val_precision: 0.7555 - val_recall: 0.6918 - val_top_1_accuracy: 0.7090 - val_top_5_accuracy: 0.9269
# Epoch 80/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step/step - accuracy: 0.9896 - loss: 0.0471 - precision: 0.9981 - recall: 0.9882 - top_1_accuracy: 0.9896 - top_5_accuracy: 0.992
# Epoch 80: Metrics logged.
# Model checkpoint saved at: /kaggle/working/model-80-val_acc_0.7104.keras
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 368s 1s/step - accuracy: 0.9896 - loss: 0.0471 - precision: 0.9981 - recall: 0.9882 - top_1_accuracy: 0.9896 - top_5_accuracy: 0.9927 - val_accuracy: 0.7104 - val_loss: 1.4465 - val_precision: 0.7530 - val_recall: 0.6963 - val_top_1_accuracy: 0.7104 - val_top_5_accuracy: 0.9261
# Epoch 81/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step/step - accuracy: 0.9928 - loss: 0.0279 - precision: 0.9971 - recall: 0.9896 - top_1_accuracy: 0.9928 - top_5_accuracy: 0.997
# Epoch 81: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 368s 1s/step - accuracy: 0.9928 - loss: 0.0279 - precision: 0.9971 - recall: 0.9896 - top_1_accuracy: 0.9928 - top_5_accuracy: 0.9974 - val_accuracy: 0.7112 - val_loss: 1.4465 - val_precision: 0.7543 - val_recall: 0.6896 - val_top_1_accuracy: 0.7112 - val_top_5_accuracy: 0.9276
# Epoch 82/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step/step - accuracy: 0.9895 - loss: 0.0462 - precision: 0.9964 - recall: 0.9885 - top_1_accuracy: 0.9895 - top_5_accuracy: 0.993
# Epoch 82: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 368s 1s/step - accuracy: 0.9895 - loss: 0.0462 - precision: 0.9964 - recall: 0.9886 - top_1_accuracy: 0.9895 - top_5_accuracy: 0.9934 - val_accuracy: 0.7142 - val_loss: 1.4510 - val_precision: 0.7535 - val_recall: 0.6888 - val_top_1_accuracy: 0.7142 - val_top_5_accuracy: 0.9299
# Epoch 83/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step/step - accuracy: 0.9887 - loss: 0.0437 - precision: 0.9960 - recall: 0.9875 - top_1_accuracy: 0.9887 - top_5_accuracy: 0.994
# Epoch 83: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 367s 1s/step - accuracy: 0.9887 - loss: 0.0437 - precision: 0.9960 - recall: 0.9875 - top_1_accuracy: 0.9887 - top_5_accuracy: 0.9949 - val_accuracy: 0.7172 - val_loss: 1.4431 - val_precision: 0.7606 - val_recall: 0.6948 - val_top_1_accuracy: 0.7172 - val_top_5_accuracy: 0.9246
# Epoch 84/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step/step - accuracy: 0.9882 - loss: 0.0513 - precision: 0.9964 - recall: 0.9855 - top_1_accuracy: 0.9882 - top_5_accuracy: 0.993
# Epoch 84: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 366s 1s/step - accuracy: 0.9882 - loss: 0.0513 - precision: 0.9964 - recall: 0.9855 - top_1_accuracy: 0.9882 - top_5_accuracy: 0.9935 - val_accuracy: 0.7134 - val_loss: 1.4539 - val_precision: 0.7514 - val_recall: 0.6925 - val_top_1_accuracy: 0.7134 - val_top_5_accuracy: 0.9246
# Epoch 85/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step/step - accuracy: 0.9871 - loss: 0.0468 - precision: 0.9942 - recall: 0.9853 - top_1_accuracy: 0.9871 - top_5_accuracy: 0.994
# Epoch 85: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 368s 1s/step - accuracy: 0.9871 - loss: 0.0468 - precision: 0.9942 - recall: 0.9853 - top_1_accuracy: 0.9871 - top_5_accuracy: 0.9947 - val_accuracy: 0.7112 - val_loss: 1.4570 - val_precision: 0.7466 - val_recall: 0.6925 - val_top_1_accuracy: 0.7112 - val_top_5_accuracy: 0.9246
# Epoch 86/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step/step - accuracy: 0.9888 - loss: 0.0497 - precision: 0.9964 - recall: 0.9862 - top_1_accuracy: 0.9888 - top_5_accuracy: 0.994
# Epoch 86: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 366s 1s/step - accuracy: 0.9888 - loss: 0.0497 - precision: 0.9964 - recall: 0.9862 - top_1_accuracy: 0.9888 - top_5_accuracy: 0.9942 - val_accuracy: 0.7127 - val_loss: 1.4340 - val_precision: 0.7598 - val_recall: 0.6963 - val_top_1_accuracy: 0.7127 - val_top_5_accuracy: 0.9284
# Epoch 87/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step/step - accuracy: 0.9921 - loss: 0.0284 - precision: 0.9963 - recall: 0.9902 - top_1_accuracy: 0.9921 - top_5_accuracy: 0.997
# Epoch 87: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 366s 1s/step - accuracy: 0.9921 - loss: 0.0285 - precision: 0.9963 - recall: 0.9902 - top_1_accuracy: 0.9921 - top_5_accuracy: 0.9975 - val_accuracy: 0.7157 - val_loss: 1.4360 - val_precision: 0.7543 - val_recall: 0.6918 - val_top_1_accuracy: 0.7157 - val_top_5_accuracy: 0.9284
# Epoch 88/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step/step - accuracy: 0.9944 - loss: 0.0287 - precision: 0.9975 - recall: 0.9918 - top_1_accuracy: 0.9944 - top_5_accuracy: 0.997
# Epoch 88: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 367s 1s/step - accuracy: 0.9944 - loss: 0.0288 - precision: 0.9975 - recall: 0.9917 - top_1_accuracy: 0.9944 - top_5_accuracy: 0.9977 - val_accuracy: 0.7157 - val_loss: 1.4397 - val_precision: 0.7571 - val_recall: 0.6933 - val_top_1_accuracy: 0.7157 - val_top_5_accuracy: 0.9276
# Epoch 89/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step/step - accuracy: 0.9910 - loss: 0.0405 - precision: 0.9983 - recall: 0.9901 - top_1_accuracy: 0.9910 - top_5_accuracy: 0.993
# Epoch 89: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 367s 1s/step - accuracy: 0.9910 - loss: 0.0405 - precision: 0.9983 - recall: 0.9901 - top_1_accuracy: 0.9910 - top_5_accuracy: 0.9936 - val_accuracy: 0.7149 - val_loss: 1.4435 - val_precision: 0.7565 - val_recall: 0.6955 - val_top_1_accuracy: 0.7149 - val_top_5_accuracy: 0.9284
# Epoch 90/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step/step - accuracy: 0.9921 - loss: 0.0337 - precision: 0.9972 - recall: 0.9902 - top_1_accuracy: 0.9921 - top_5_accuracy: 0.996
# Epoch 90: Metrics logged.
# Model checkpoint saved at: /kaggle/working/model-90-val_acc_0.7179.keras
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 367s 1s/step - accuracy: 0.9921 - loss: 0.0338 - precision: 0.9972 - recall: 0.9902 - top_1_accuracy: 0.9921 - top_5_accuracy: 0.9962 - val_accuracy: 0.7179 - val_loss: 1.4363 - val_precision: 0.7571 - val_recall: 0.6933 - val_top_1_accuracy: 0.7179 - val_top_5_accuracy: 0.9269
# Epoch 91/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/
130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step/step - accuracy: 0.9910 - loss: 0.0322 - precision: 0.9962 - recall: 0.9897 - top_1_accuracy: 0.9910 - top_5_accuracy: 0.996
# Epoch 97: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 369s 1s/step - accuracy: 0.9910 - loss: 0.0322 - precision: 0.9962 - recall: 0.9897 - top_1_accuracy: 0.9910 - top_5_accuracy: 0.9967 - val_accuracy: 0.7142 - val_loss: 1.4343 - val_precision: 0.7575 - val_recall: 0.6948 - val_top_1_accuracy: 0.7142 - val_top_5_accuracy: 0.9254
# Epoch 98/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step/step - accuracy: 0.9908 - loss: 0.0375 - precision: 0.9968 - recall: 0.9895 - top_1_accuracy: 0.9908 - top_5_accuracy: 0.995
# Epoch 98: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 369s 1s/step - accuracy: 0.9908 - loss: 0.0375 - precision: 0.9968 - recall: 0.9895 - top_1_accuracy: 0.9908 - top_5_accuracy: 0.9950 - val_accuracy: 0.7157 - val_loss: 1.4354 - val_precision: 0.7520 - val_recall: 0.6948 - val_top_1_accuracy: 0.7157 - val_top_5_accuracy: 0.9261
# Epoch 99/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step/step - accuracy: 0.9913 - loss: 0.0366 - precision: 0.9967 - recall: 0.9904 - top_1_accuracy: 0.9913 - top_5_accuracy: 0.995
# Epoch 99: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 370s 1s/step - accuracy: 0.9913 - loss: 0.0366 - precision: 0.9967 - recall: 0.9904 - top_1_accuracy: 0.9913 - top_5_accuracy: 0.9957 - val_accuracy: 0.7112 - val_loss: 1.4456 - val_precision: 0.7543 - val_recall: 0.6940 - val_top_1_accuracy: 0.7112 - val_top_5_accuracy: 0.9276
# Epoch 100/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step/step - accuracy: 0.9935 - loss: 0.0281 - precision: 0.9979 - recall: 0.9926 - top_1_accuracy: 0.9935 - top_5_accuracy: 0.995
# Epoch 100: Metrics logged.
# Model checkpoint saved at: /kaggle/working/model-100-val_acc_0.7134.keras
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 370s 1s/step - accuracy: 0.9935 - loss: 0.0281 - precision: 0.9979 - recall: 0.9926 - top_1_accuracy: 0.9935 - top_5_accuracy: 0.9953 - val_accuracy: 0.7134 - val_loss: 1.4379 - val_precision: 0.7512 - val_recall: 0.6963 - val_top_1_accuracy: 0.7134 - val_top_5_accuracy: 0.9284
# Epoch 101/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step/step - accuracy: 0.9922 - loss: 0.0336 - precision: 0.9978 - recall: 0.9893 - top_1_accuracy: 0.9922 - top_5_accuracy: 0.995
# Epoch 101: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 357s 979ms/step - accuracy: 0.9922 - loss: 0.0336 - precision: 0.9978 - recall: 0.9893 - top_1_accuracy: 0.9922 - top_5_accuracy: 0.9958 - val_accuracy: 0.7157 - val_loss: 1.4423 - val_precision: 0.7522 - val_recall: 0.6933 - val_top_1_accuracy: 0.7157 - val_top_5_accuracy: 0.9261
# Epoch 102/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step/step - accuracy: 0.9912 - loss: 0.0340 - precision: 0.9953 - recall: 0.9903 - top_1_accuracy: 0.9912 - top_5_accuracy: 0.995
# Epoch 102: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 356s 975ms/step - accuracy: 0.9912 - loss: 0.0341 - precision: 0.9953 - recall: 0.9903 - top_1_accuracy: 0.9912 - top_5_accuracy: 0.9955 - val_accuracy: 0.7127 - val_loss: 1.4437 - val_precision: 0.7541 - val_recall: 0.6910 - val_top_1_accuracy: 0.7127 - val_top_5_accuracy: 0.9246
# Epoch 103/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step/step - accuracy: 0.9948 - loss: 0.0270 - precision: 0.9986 - recall: 0.9930 - top_1_accuracy: 0.9948 - top_5_accuracy: 0.996
# Epoch 103: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 356s 975ms/step - accuracy: 0.9948 - loss: 0.0270 - precision: 0.9986 - recall: 0.9930 - top_1_accuracy: 0.9948 - top_5_accuracy: 0.9966 - val_accuracy: 0.7104 - val_loss: 1.4362 - val_precision: 0.7577 - val_recall: 0.6933 - val_top_1_accuracy: 0.7104 - val_top_5_accuracy: 0.9261
# Epoch 104/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step/step - accuracy: 0.9908 - loss: 0.0400 - precision: 0.9978 - recall: 0.9896 - top_1_accuracy: 0.9908 - top_5_accuracy: 0.994
# Epoch 104: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 356s 975ms/step - accuracy: 0.9908 - loss: 0.0400 - precision: 0.9978 - recall: 0.9896 - top_1_accuracy: 0.9908 - top_5_accuracy: 0.9945 - val_accuracy: 0.7119 - val_loss: 1.4460 - val_precision: 0.7528 - val_recall: 0.6955 - val_top_1_accuracy: 0.7119 - val_top_5_accuracy: 0.9261
# Epoch 105/130
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 930ms/step - accuracy: 0.9932 - loss: 0.0300 - precision: 0.9978 - recall: 0.9914 - top_1_accuracy: 0.9932 - top_5_accuracy: 0.9967
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 hist=model.fit(
#       2     train_generator,
#       3     epochs=130,
#       4     validation_data=validation_generator,
#       5     shuffle=True,
#       6     callbacks=metrics_and_checkpoint_callback) #start training
#
# File /opt/conda/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/conda/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py:339, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     328 if getattr(self, "_eval_epoch_iterator", None) is None:
#     329     self._eval_epoch_iterator = TFEpochIterator(
#     330         x=val_x,
#     331         y=val_y,
#    (...)
#     337         shuffle=False,
#     338     )
# --> 339 val_logs = self.evaluate(
#     340     x=val_x,
#     341     y=val_y,
#     342     sample_weight=val_sample_weight,
#     343     batch_size=validation_batch_size or batch_size,
#     344     steps=validation_steps,
#     345     callbacks=callbacks,
#     346     return_dict=True,
#     347     _use_cached_eval_dataset=True,
#     348 )
#     349 val_logs = {
#     350     "val_" + name: val for name, val in val_logs.items()
#     351 }
#     352 epoch_logs.update(val_logs)
#
# File /opt/conda/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/conda/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py:425, in TensorFlowTrainer.evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, return_dict, **kwargs)
#     423 for step, iterator in epoch_iterator.enumerate_epoch():
#     424     callbacks.on_test_batch_begin(step)
# --> 425     logs = self.test_function(iterator)
#     426     logs = self._pythonify_logs(logs)
#     427     callbacks.on_test_batch_end(step, logs)
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/context.py:1500, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1498 cancellation_context = cancellation.context()
#    1499 if cancellation_context is None:
# -> 1500   outputs = execute.execute(
#    1501       name.decode("utf-8"),
#    1502       num_outputs=num_outputs,
#    1503       inputs=tensor_inputs,
#    1504       attrs=attrs,
#    1505       ctx=self,
#    1506   )
#    1507 else:
#    1508   outputs = execute.execute_with_cancellation(
#    1509       name.decode("utf-8"),
#    1510       num_outputs=num_outputs,
#    (...)
#    1514       cancellation_manager=cancellation_context,
#    1515   )
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
import kagglehub

kagglehub.login()

# Replace with path to directory containing model files.
LOCAL_MODEL_DIR = 'path to the last checkpoint you want to save'

MODEL_SLUG = 'my_model' # Replace with model slug.

# Learn more about naming model variations at
# https://www.kaggle.com/docs/models#name-model.
VARIATION_SLUG = 'default' # Replace with variation slug.

kagglehub.model_upload(
  handle = f"use you handle info to save the checkpoint directly on your kaggle ID",
  local_model_dir = LOCAL_MODEL_DIR,
  version_notes = 'version update dates')
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://www.kaggle.com/static/images/site-logo.png\nalt=\'Kaggle…
# Uploading Model https://www.kaggle.com/models/kartikgarg74/my_model/keras/default ...
# Model 'my_model' does not exist or access is forbidden for user 'kartikgarg74'. Creating or handling Model...
# Warning: Looks like you're using an outdated `kagglehub` version, please consider updating (latest version: 0.3.5)
# Model 'my_model' Created.
# Starting upload for file /kaggle/working/model-100-val_acc_0.7134.keras
# Warning: Looks like you're using an outdated `kagglehub` version, please consider updating (latest version: 0.3.5)
# Uploading: 100%|██████████| 33.8M/33.8M [00:00<00:00, 34.1MB/s]
# Upload successful: /kaggle/working/model-100-val_acc_0.7134.keras (32MB)
# Warning: Looks like you're using an outdated `kagglehub` version, please consider updating (latest version: 0.3.5)
# Your model instance has been created.
# Files are being processed...
# See at: https://www.kaggle.com/models/kartikgarg74/my_model/keras/default

# %%
import tensorflow as tf
# Path to the checkpoint and metrics log
checkpoint_path = 'path to the last saved checkpoint'
# Load the model from the checkpoint
model = keras.models.load_model(checkpoint_path)

validation_data = next(iter(validation_generator))
# Resume training
history = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=130,  # Train for the remaining epochs
    callbacks=[metrics_and_checkpoint_callback],
    initial_epoch=# last saved epoch
)
# Out:
# Epoch 101/130
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1734233839.056444     107 service.cc:145] XLA service 0x7f2330006ed0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1734233839.056512     107 service.cc:153]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1734233839.056517     107 service.cc:153]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# 2024-12-15 03:37:46.750352: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng4{} for conv (f32[15,96,257,257]{3,2,1,0}, u8[0]{0}) custom-call(f32[15,96,259,259]{3,2,1,0}, f32[96,1,3,3]{3,2,1,0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, feature_group_count=96, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2024-12-15 03:37:46.881689: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.131426874s
# Trying algorithm eng4{} for conv (f32[15,96,257,257]{3,2,1,0}, u8[0]{0}) custom-call(f32[15,96,259,259]{3,2,1,0}, f32[96,1,3,3]{3,2,1,0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, feature_group_count=96, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# I0000 00:00:1734233896.783153     107 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/stepstep - accuracy: 0.9897 - loss: 0.0387 - precision: 0.9975 - recall: 0.9896 - top_1_accuracy: 0.9897 - top_5_accuracy: 0.994
# Epoch 101: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 523s 1s/step - accuracy: 0.9897 - loss: 0.0387 - precision: 0.9975 - recall: 0.9896 - top_1_accuracy: 0.9897 - top_5_accuracy: 0.9941 - val_accuracy: 0.7149 - val_loss: 1.4478 - val_precision: 0.7555 - val_recall: 0.6963 - val_top_1_accuracy: 0.7149 - val_top_5_accuracy: 0.9261
# Epoch 102/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/stepep - accuracy: 0.9882 - loss: 0.0484 - precision: 0.9969 - recall: 0.9870 - top_1_accuracy: 0.9882 - top_5_accuracy: 0.993
# Epoch 102: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 395s 1s/step - accuracy: 0.9882 - loss: 0.0483 - precision: 0.9969 - recall: 0.9870 - top_1_accuracy: 0.9882 - top_5_accuracy: 0.9934 - val_accuracy: 0.7104 - val_loss: 1.4359 - val_precision: 0.7496 - val_recall: 0.6925 - val_top_1_accuracy: 0.7104 - val_top_5_accuracy: 0.9276
# Epoch 103/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/stepep - accuracy: 0.9901 - loss: 0.0392 - precision: 0.9972 - recall: 0.9899 - top_1_accuracy: 0.9901 - top_5_accuracy: 0.993
# Epoch 103: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 397s 1s/step - accuracy: 0.9901 - loss: 0.0392 - precision: 0.9972 - recall: 0.9899 - top_1_accuracy: 0.9901 - top_5_accuracy: 0.9938 - val_accuracy: 0.7157 - val_loss: 1.4547 - val_precision: 0.7498 - val_recall: 0.6933 - val_top_1_accuracy: 0.7157 - val_top_5_accuracy: 0.9254
# Epoch 104/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/stepep - accuracy: 0.9888 - loss: 0.0427 - precision: 0.9964 - recall: 0.9876 - top_1_accuracy: 0.9888 - top_5_accuracy: 0.995
# Epoch 104: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 398s 1s/step - accuracy: 0.9888 - loss: 0.0426 - precision: 0.9964 - recall: 0.9876 - top_1_accuracy: 0.9888 - top_5_accuracy: 0.9951 - val_accuracy: 0.7119 - val_loss: 1.4464 - val_precision: 0.7490 - val_recall: 0.6970 - val_top_1_accuracy: 0.7119 - val_top_5_accuracy: 0.9254
# Epoch 105/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/stepep - accuracy: 0.9892 - loss: 0.0434 - precision: 0.9962 - recall: 0.9889 - top_1_accuracy: 0.9892 - top_5_accuracy: 0.994
# Epoch 105: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 397s 1s/step - accuracy: 0.9892 - loss: 0.0434 - precision: 0.9962 - recall: 0.9889 - top_1_accuracy: 0.9892 - top_5_accuracy: 0.9947 - val_accuracy: 0.7149 - val_loss: 1.4461 - val_precision: 0.7548 - val_recall: 0.6985 - val_top_1_accuracy: 0.7149 - val_top_5_accuracy: 0.9269
# Epoch 106/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/stepep - accuracy: 0.9944 - loss: 0.0230 - precision: 0.9988 - recall: 0.9930 - top_1_accuracy: 0.9944 - top_5_accuracy: 0.997
# Epoch 106: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 398s 1s/step - accuracy: 0.9943 - loss: 0.0230 - precision: 0.9988 - recall: 0.9930 - top_1_accuracy: 0.9943 - top_5_accuracy: 0.9979 - val_accuracy: 0.7142 - val_loss: 1.4553 - val_precision: 0.7544 - val_recall: 0.6993 - val_top_1_accuracy: 0.7142 - val_top_5_accuracy: 0.9254
# Epoch 107/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/stepep - accuracy: 0.9894 - loss: 0.0438 - precision: 0.9970 - recall: 0.9880 - top_1_accuracy: 0.9894 - top_5_accuracy: 0.993
# Epoch 107: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 396s 1s/step - accuracy: 0.9894 - loss: 0.0437 - precision: 0.9970 - recall: 0.9880 - top_1_accuracy: 0.9894 - top_5_accuracy: 0.9933 - val_accuracy: 0.7127 - val_loss: 1.4520 - val_precision: 0.7506 - val_recall: 0.6963 - val_top_1_accuracy: 0.7127 - val_top_5_accuracy: 0.9246
# Epoch 108/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/stepep - accuracy: 0.9902 - loss: 0.0373 - precision: 0.9977 - recall: 0.9892 - top_1_accuracy: 0.9902 - top_5_accuracy: 0.995
# Epoch 108: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 398s 1s/step - accuracy: 0.9902 - loss: 0.0373 - precision: 0.9977 - recall: 0.9892 - top_1_accuracy: 0.9902 - top_5_accuracy: 0.9951 - val_accuracy: 0.7112 - val_loss: 1.4459 - val_precision: 0.7530 - val_recall: 0.6918 - val_top_1_accuracy: 0.7112 - val_top_5_accuracy: 0.9254
# Epoch 109/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/stepep - accuracy: 0.9915 - loss: 0.0272 - precision: 0.9956 - recall: 0.9897 - top_1_accuracy: 0.9915 - top_5_accuracy: 0.997
# Epoch 109: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 399s 1s/step - accuracy: 0.9915 - loss: 0.0272 - precision: 0.9956 - recall: 0.9897 - top_1_accuracy: 0.9915 - top_5_accuracy: 0.9978 - val_accuracy: 0.7112 - val_loss: 1.4467 - val_precision: 0.7534 - val_recall: 0.6955 - val_top_1_accuracy: 0.7112 - val_top_5_accuracy: 0.9284
# Epoch 110/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/stepep - accuracy: 0.9934 - loss: 0.0297 - precision: 0.9983 - recall: 0.9916 - top_1_accuracy: 0.9934 - top_5_accuracy: 0.995
# Epoch 110: Metrics logged.
# Model checkpoint saved at: /kaggle/working/model-110-val_acc_0.7119.keras
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 398s 1s/step - accuracy: 0.9934 - loss: 0.0297 - precision: 0.9983 - recall: 0.9916 - top_1_accuracy: 0.9934 - top_5_accuracy: 0.9956 - val_accuracy: 0.7119 - val_loss: 1.4521 - val_precision: 0.7492 - val_recall: 0.6933 - val_top_1_accuracy: 0.7119 - val_top_5_accuracy: 0.9254
# Epoch 111/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/stepep - accuracy: 0.9900 - loss: 0.0417 - precision: 0.9955 - recall: 0.9891 - top_1_accuracy: 0.9900 - top_5_accuracy: 0.994
# Epoch 111: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 398s 1s/step - accuracy: 0.9900 - loss: 0.0417 - precision: 0.9955 - recall: 0.9891 - top_1_accuracy: 0.9900 - top_5_accuracy: 0.9944 - val_accuracy: 0.7142 - val_loss: 1.4469 - val_precision: 0.7520 - val_recall: 0.6970 - val_top_1_accuracy: 0.7142 - val_top_5_accuracy: 0.9254
# Epoch 112/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/stepep - accuracy: 0.9918 - loss: 0.0329 - precision: 0.9979 - recall: 0.9902 - top_1_accuracy: 0.9918 - top_5_accuracy: 0.995
# Epoch 112: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 394s 1s/step - accuracy: 0.9918 - loss: 0.0329 - precision: 0.9979 - recall: 0.9902 - top_1_accuracy: 0.9918 - top_5_accuracy: 0.9956 - val_accuracy: 0.7157 - val_loss: 1.4458 - val_precision: 0.7518 - val_recall: 0.6985 - val_top_1_accuracy: 0.7157 - val_top_5_accuracy: 0.9261
# Epoch 113/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/stepep - accuracy: 0.9910 - loss: 0.0428 - precision: 0.9965 - recall: 0.9887 - top_1_accuracy: 0.9910 - top_5_accuracy: 0.994
# Epoch 113: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 402s 1s/step - accuracy: 0.9910 - loss: 0.0428 - precision: 0.9965 - recall: 0.9887 - top_1_accuracy: 0.9910 - top_5_accuracy: 0.9946 - val_accuracy: 0.7149 - val_loss: 1.4442 - val_precision: 0.7575 - val_recall: 0.6948 - val_top_1_accuracy: 0.7149 - val_top_5_accuracy: 0.9269
# Epoch 114/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/stepep - accuracy: 0.9927 - loss: 0.0288 - precision: 0.9987 - recall: 0.9918 - top_1_accuracy: 0.9927 - top_5_accuracy: 0.997
# Epoch 114: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 400s 1s/step - accuracy: 0.9927 - loss: 0.0288 - precision: 0.9987 - recall: 0.9918 - top_1_accuracy: 0.9927 - top_5_accuracy: 0.9970 - val_accuracy: 0.7119 - val_loss: 1.4472 - val_precision: 0.7557 - val_recall: 0.6948 - val_top_1_accuracy: 0.7119 - val_top_5_accuracy: 0.9276
# Epoch 115/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/stepep - accuracy: 0.9926 - loss: 0.0297 - precision: 0.9970 - recall: 0.9910 - top_1_accuracy: 0.9926 - top_5_accuracy: 0.996
# Epoch 115: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 398s 1s/step - accuracy: 0.9926 - loss: 0.0297 - precision: 0.9970 - recall: 0.9910 - top_1_accuracy: 0.9926 - top_5_accuracy: 0.9965 - val_accuracy: 0.7142 - val_loss: 1.4436 - val_precision: 0.7528 - val_recall: 0.6955 - val_top_1_accuracy: 0.7142 - val_top_5_accuracy: 0.9276
# Epoch 116/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/stepep - accuracy: 0.9897 - loss: 0.0436 - precision: 0.9978 - recall: 0.9891 - top_1_accuracy: 0.9897 - top_5_accuracy: 0.992
# Epoch 116: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 396s 1s/step - accuracy: 0.9897 - loss: 0.0436 - precision: 0.9978 - recall: 0.9891 - top_1_accuracy: 0.9897 - top_5_accuracy: 0.9926 - val_accuracy: 0.7134 - val_loss: 1.4459 - val_precision: 0.7522 - val_recall: 0.6955 - val_top_1_accuracy: 0.7134 - val_top_5_accuracy: 0.9291
# Epoch 117/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/stepep - accuracy: 0.9919 - loss: 0.0364 - precision: 0.9986 - recall: 0.9899 - top_1_accuracy: 0.9919 - top_5_accuracy: 0.995
# Epoch 117: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 392s 1s/step - accuracy: 0.9919 - loss: 0.0364 - precision: 0.9986 - recall: 0.9899 - top_1_accuracy: 0.9919 - top_5_accuracy: 0.9953 - val_accuracy: 0.7104 - val_loss: 1.4488 - val_precision: 0.7498 - val_recall: 0.6933 - val_top_1_accuracy: 0.7104 - val_top_5_accuracy: 0.9269
# Epoch 118/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/stepep - accuracy: 0.9922 - loss: 0.0346 - precision: 0.9986 - recall: 0.9912 - top_1_accuracy: 0.9922 - top_5_accuracy: 0.994
# Epoch 118: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 391s 1s/step - accuracy: 0.9922 - loss: 0.0346 - precision: 0.9986 - recall: 0.9912 - top_1_accuracy: 0.9922 - top_5_accuracy: 0.9945 - val_accuracy: 0.7127 - val_loss: 1.4443 - val_precision: 0.7500 - val_recall: 0.6940 - val_top_1_accuracy: 0.7127 - val_top_5_accuracy: 0.9269
# Epoch 119/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/stepep - accuracy: 0.9921 - loss: 0.0335 - precision: 0.9983 - recall: 0.9904 - top_1_accuracy: 0.9921 - top_5_accuracy: 0.995
# Epoch 119: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 390s 1s/step - accuracy: 0.9921 - loss: 0.0335 - precision: 0.9983 - recall: 0.9904 - top_1_accuracy: 0.9921 - top_5_accuracy: 0.9958 - val_accuracy: 0.7119 - val_loss: 1.4540 - val_precision: 0.7476 - val_recall: 0.6940 - val_top_1_accuracy: 0.7119 - val_top_5_accuracy: 0.9291
# Epoch 120/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/stepep - accuracy: 0.9917 - loss: 0.0349 - precision: 0.9976 - recall: 0.9907 - top_1_accuracy: 0.9917 - top_5_accuracy: 0.995
# Epoch 120: Metrics logged.
# Model checkpoint saved at: /kaggle/working/model-120-val_acc_0.7142.keras
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 392s 1s/step - accuracy: 0.9917 - loss: 0.0349 - precision: 0.9976 - recall: 0.9907 - top_1_accuracy: 0.9917 - top_5_accuracy: 0.9954 - val_accuracy: 0.7142 - val_loss: 1.4578 - val_precision: 0.7506 - val_recall: 0.6940 - val_top_1_accuracy: 0.7142 - val_top_5_accuracy: 0.9284
# Epoch 121/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/stepep - accuracy: 0.9918 - loss: 0.0360 - precision: 0.9981 - recall: 0.9904 - top_1_accuracy: 0.9918 - top_5_accuracy: 0.994
# Epoch 121: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 388s 1s/step - accuracy: 0.9918 - loss: 0.0360 - precision: 0.9981 - recall: 0.9904 - top_1_accuracy: 0.9918 - top_5_accuracy: 0.9945 - val_accuracy: 0.7112 - val_loss: 1.4522 - val_precision: 0.7512 - val_recall: 0.6918 - val_top_1_accuracy: 0.7112 - val_top_5_accuracy: 0.9276
# Epoch 122/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/stepep - accuracy: 0.9937 - loss: 0.0275 - precision: 0.9982 - recall: 0.9922 - top_1_accuracy: 0.9937 - top_5_accuracy: 0.996
# Epoch 122: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 401s 1s/step - accuracy: 0.9937 - loss: 0.0275 - precision: 0.9982 - recall: 0.9922 - top_1_accuracy: 0.9937 - top_5_accuracy: 0.9968 - val_accuracy: 0.7112 - val_loss: 1.4542 - val_precision: 0.7512 - val_recall: 0.6918 - val_top_1_accuracy: 0.7112 - val_top_5_accuracy: 0.9269
# Epoch 123/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/stepep - accuracy: 0.9919 - loss: 0.0323 - precision: 0.9968 - recall: 0.9912 - top_1_accuracy: 0.9919 - top_5_accuracy: 0.995
# Epoch 123: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 391s 1s/step - accuracy: 0.9919 - loss: 0.0323 - precision: 0.9968 - recall: 0.9912 - top_1_accuracy: 0.9919 - top_5_accuracy: 0.9955 - val_accuracy: 0.7157 - val_loss: 1.4420 - val_precision: 0.7512 - val_recall: 0.6963 - val_top_1_accuracy: 0.7157 - val_top_5_accuracy: 0.9291
# Epoch 124/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/stepep - accuracy: 0.9933 - loss: 0.0328 - precision: 0.9984 - recall: 0.9911 - top_1_accuracy: 0.9933 - top_5_accuracy: 0.995
# Epoch 124: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 392s 1s/step - accuracy: 0.9933 - loss: 0.0328 - precision: 0.9984 - recall: 0.9911 - top_1_accuracy: 0.9933 - top_5_accuracy: 0.9955 - val_accuracy: 0.7082 - val_loss: 1.4435 - val_precision: 0.7561 - val_recall: 0.6940 - val_top_1_accuracy: 0.7082 - val_top_5_accuracy: 0.9269
# Epoch 125/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/stepep - accuracy: 0.9941 - loss: 0.0269 - precision: 0.9984 - recall: 0.9924 - top_1_accuracy: 0.9941 - top_5_accuracy: 0.996
# Epoch 125: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 390s 1s/step - accuracy: 0.9941 - loss: 0.0270 - precision: 0.9984 - recall: 0.9924 - top_1_accuracy: 0.9941 - top_5_accuracy: 0.9969 - val_accuracy: 0.7090 - val_loss: 1.4403 - val_precision: 0.7555 - val_recall: 0.6918 - val_top_1_accuracy: 0.7090 - val_top_5_accuracy: 0.9276
# Epoch 126/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/stepep - accuracy: 0.9933 - loss: 0.0267 - precision: 0.9968 - recall: 0.9929 - top_1_accuracy: 0.9933 - top_5_accuracy: 0.996
# Epoch 126: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 390s 1s/step - accuracy: 0.9932 - loss: 0.0268 - precision: 0.9968 - recall: 0.9929 - top_1_accuracy: 0.9932 - top_5_accuracy: 0.9966 - val_accuracy: 0.7104 - val_loss: 1.4481 - val_precision: 0.7498 - val_recall: 0.6910 - val_top_1_accuracy: 0.7104 - val_top_5_accuracy: 0.9269
# Epoch 127/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/stepep - accuracy: 0.9909 - loss: 0.0367 - precision: 0.9977 - recall: 0.9902 - top_1_accuracy: 0.9909 - top_5_accuracy: 0.994
# Epoch 127: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 389s 1s/step - accuracy: 0.9909 - loss: 0.0367 - precision: 0.9977 - recall: 0.9902 - top_1_accuracy: 0.9909 - top_5_accuracy: 0.9942 - val_accuracy: 0.7097 - val_loss: 1.4424 - val_precision: 0.7504 - val_recall: 0.6910 - val_top_1_accuracy: 0.7097 - val_top_5_accuracy: 0.9276
# Epoch 128/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/stepep - accuracy: 0.9916 - loss: 0.0370 - precision: 0.9977 - recall: 0.9910 - top_1_accuracy: 0.9916 - top_5_accuracy: 0.994
# Epoch 128: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 392s 1s/step - accuracy: 0.9916 - loss: 0.0370 - precision: 0.9977 - recall: 0.9910 - top_1_accuracy: 0.9916 - top_5_accuracy: 0.9942 - val_accuracy: 0.7157 - val_loss: 1.4436 - val_precision: 0.7559 - val_recall: 0.6955 - val_top_1_accuracy: 0.7157 - val_top_5_accuracy: 0.9291
# Epoch 129/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/stepep - accuracy: 0.9916 - loss: 0.0327 - precision: 0.9972 - recall: 0.9904 - top_1_accuracy: 0.9916 - top_5_accuracy: 0.995
# Epoch 129: Metrics logged.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 390s 1s/step - accuracy: 0.9916 - loss: 0.0327 - precision: 0.9972 - recall: 0.9904 - top_1_accuracy: 0.9916 - top_5_accuracy: 0.9954 - val_accuracy: 0.7142 - val_loss: 1.4439 - val_precision: 0.7524 - val_recall: 0.6963 - val_top_1_accuracy: 0.7142 - val_top_5_accuracy: 0.9261
# Epoch 130/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/stepep - accuracy: 0.9916 - loss: 0.0404 - precision: 0.9979 - recall: 0.9897 - top_1_accuracy: 0.9916 - top_5_accuracy: 0.994
# Epoch 130: Metrics logged.
# Model checkpoint saved at: /kaggle/working/model-130-val_acc_0.7142.keras
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 392s 1s/step - accuracy: 0.9916 - loss: 0.0404 - precision: 0.9979 - recall: 0.9897 - top_1_accuracy: 0.9916 - top_5_accuracy: 0.9945 - val_accuracy: 0.7142 - val_loss: 1.4469 - val_precision: 0.7506 - val_recall: 0.6918 - val_top_1_accuracy: 0.7142 - val_top_5_accuracy: 0.9239

# %%
import kagglehub

kagglehub.login()

# Replace with path to directory containing model files.
LOCAL_MODEL_DIR = '/kaggle/working/model-130-val_acc_0.7142.keras'

MODEL_SLUG = 'my_model' # Replace with model slug.

# Learn more about naming model variations at
# https://www.kaggle.com/docs/models#name-model.
VARIATION_SLUG = 'default' # Replace with variation slug.

kagglehub.model_upload(
  handle = f"kartikgarg74/{MODEL_SLUG}/keras/{VARIATION_SLUG}",
  local_model_dir = LOCAL_MODEL_DIR,
  version_notes = 'Update 2024-12-14')
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://www.kaggle.com/static/images/site-logo.png\nalt=\'Kaggle…
# Uploading Model https://www.kaggle.com/models/kartikgarg74/my_model/keras/default ...
# Warning: Looks like you're using an outdated `kagglehub` version, please consider updating (latest version: 0.3.5)
# Starting upload for file /kaggle/working/model-130-val_acc_0.7142.keras
# Warning: Looks like you're using an outdated `kagglehub` version, please consider updating (latest version: 0.3.5)
# Uploading: 100%|██████████| 33.8M/33.8M [00:00<00:00, 53.0MB/s]
# Upload successful: /kaggle/working/model-130-val_acc_0.7142.keras (32MB)
# Warning: Looks like you're using an outdated `kagglehub` version, please consider updating (latest version: 0.3.5)
# Your model instance version has been created.
# Files are being processed...
# See at: https://www.kaggle.com/models/kartikgarg74/my_model/keras/default
